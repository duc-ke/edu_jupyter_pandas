# %% [markdown]
# <a href="https://colab.research.google.com/github/duc-ke/edu_jupyter_pandas/blob/master/pandas_basic_grammar(colab).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # [Pandas 기본 개념]
# ------------------------------

# %% [markdown]
# ![image.png](attachment:image.png)
#
# pandas는 효과적인 데이터분석을 지원하는 python 모듈. R에서 자주 사용되는 DataFrame, 즉 엑셀 쉬트 같은 2차원 테이블 데이터를 파이썬에서도 좀더 파이썬스럽게 사용가능. 이전에는 데이터 분석한다 하면, R로만 해야하는 경우가 많았었는데, pandas가 등장한 뒤로, 파이썬에서도 손쉽게 DataFrame 데이터를 다루고, 프로그래밍할 수 있게 되었음.
#
# ----------------------

# %% [markdown]
# **pandas사용할 줄 안다 라고 하기위해 할수 있어야 하는 작업들**

# %%
from wand.image import Image as WImage
img = WImage(filename='Pandas_Cheat_Sheet.pdf')
img
# Out:
# <wand.image.Image: 03cd3b4 'PDF' (1100x850)>

# %%
img = WImage(filename='Pandas_Cheat_Sheet.pdf[1]')
img
# Out:
# <wand.image.Image: 03cd3b4 'PDF' (1100x850)>

# %% [markdown]
# 참고사항) 이 jupyter notebook에는 Cheat sheet에서 아래의 3가지 주제가 빠져 있습니다.
#  1. Reshaping data의 `melt`
#  1. Reshaping data의 `pivot`
#  1. `groupby`
#
# 아래 jupyter로 연습이 끝난 후에 여유가 된다면 심화 사용법을 익히기 위해서 위의 주제로 공부를 하시는 걸 추전드려요~

# %% [markdown]
# **pandas의 두가지 데이터 타입**
#
# ![image.png](attachment:image.png)

# %% [markdown]
# **데이터 프레임의 구조**
#
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-19%2003.54.43.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-07-19%2003.54.43.png)

# %% [markdown]
# ![cat.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## pandas를 설치 해봅시다.
# `conda install pandas` (또는) `pip install pandas`

# %%
# jupyter 밖의 cmd(혹은 shell)에 접근하려면 '!' magic command 를 붙입니다.
# !pip install pandas

# %% [markdown]
# 문제 없이 잘 설치 되었다면 import시 에러가 안나겠죠?

# %%
# pandas를 import 해 봅시다.

# %% [markdown]
# # [Pandas 문법]
# ***

# %% [markdown]
# ## DataFrame 생성 + 파일 읽고 쓰기 + 행/열 삭제
# 여러 방식의 df 만드는 방법이 있음, 그 중 2가지만 봅시다

# %%
# dic을 이용한 df생성
df1 
df1
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
# list를 이용한 df생성
df2 
df2
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
# df1과 똑같이 만들기 위해 header를 넣습니다.

df2
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
# 결과 파일 생성해보고 파일 열어 확인해봅시다.
df2.to_csv("dataset/tmp.csv")

# %% [markdown]
# Q?
# * python과 비교하여 파일 쓰는 장점이 보이나요?
# * index를 안쓰고 싶다면?

# %%
df2.to_csv("dataset/tmp2.csv", index=False)

# %%
# 쓴 파일 다시 읽어 봅시다.
df2_read = pd.
df2_read
# Out:
#    Unnamed: 0  a  b  c
# 0           0  1  2  3
# 1           1  4  5  6
# 2           2  7  8  9

# %% [markdown]
# 아래 그림처럼 원하지 않은 col이 들어오면 어떻게 처리할까요?
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-08-21%2011.14.27.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-08-21%2011.14.27.png)

# %%
# 방법 1. index 열을 지정합니다.
df3_read = pd.read_csv("dataset/tmp.csv", )
df3_read
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
# 방법 2.특정 열을 제거합니다.
# 그러기 위해서 header를 출력해 봅시다.
df2_read
# Out:
# Index(['Unnamed: 0', 'a', 'b', 'c'], dtype='object')

# %%
# 필요 없는 열을 제거합니다.(drop)
df2_read.drop()
# Out:
#    Unnamed: 0  a  b  c
# 1           1  4  5  6
# 2           2  7  8  9

# %%
# 제거 하고 난뒤 df를 출력해 볼까요?
df2_read
# Out:
#    Unnamed: 0  a  b  c
# 0           0  1  2  3
# 1           1  4  5  6
# 2           2  7  8  9

# %%
# 제거 한뒤에 새로운 df에 저장해야 합니다.
df4_read = df2_read.drop(["Unnamed: 0"], axis=1)
df4_read
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
# 그럼 행(index가 0)을 제거 하고싶다면?(drop)
# Out:
#    Unnamed: 0  a  b  c
# 1           1  4  5  6
# 2           2  7  8  9

# %% [markdown]
# ## Subset 만들기
# 내가 원하는 col혹은 row를 선택하거나 특정 데이터 일부를 선택하는 방법을 배워 봅시다.

# %%
# 예제용 샘플데이터 셋을 가져오기 위해 `dataset/iris_sample.csv`를 읽어봅시다.
df = pd.
df
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species
# 0            5.1          3.5           1.4          0.2     setosa
# 1            4.9          3.0           1.4          0.2     setosa
# 2            4.7          3.2           1.3          0.2     setosa
# 3            4.6          3.1           1.5          0.2     setosa
# 4            5.0          3.6           1.4          0.2     setosa
# 5            5.4          3.9           1.7          0.4     setosa
# 6            4.6          3.4           1.4          0.3     setosa
# 7            5.0          3.4           1.5          0.2     setosa
# 8            4.4          2.9           1.4          0.2     setosa
# 9            4.9          3.1           1.5          0.1     setosa
# 10           5.4          3.7           1.5          0.2     setosa
# 11           4.8          3.4           1.6          0.2     setosa
# 12           4.8          3.0           NaN          0.1     setosa
# ...

# %%
# 너무 길어요, 위에서 5줄만 읽어 봐요
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# pandas에서 DataFrame은 Series의 모임입니다. 여기선 'sepal_lengh', 'sepal_width'.. 5가지의 모임이죠.<br>
# 각 컬럼은 설택하거나 행을 선택하는 방법은 크게 두가지 입니다.(사실 축약형이 조금 더 있지만요)

# %% [markdown]
# **(1) iloc를 이용한 index이용방법**

# %%
# 첫, 셋째 행만 뽑고싶다면?
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
# 행을 선택하는 축약형도 있습니다.
df.iloc[[0,2]]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
# sepal_width, species 열만 보고싶다면?
df.iloc[]
# Out:
#     sepal_width species
# 0           3.5  setosa
# 1           3.0  setosa
# 2           3.2  setosa
# 3           3.1  setosa
# 4           3.6  setosa
# 5           3.9  setosa
# 6           3.4  setosa
# 7           3.4  setosa
# 8           2.9  setosa
# 9           3.1  setosa
# 10          3.7  setosa
# 11          3.4  setosa
# 12          3.0  setosa
# 13          3.0  setosa
# 14          4.0  setosa
# 15          4.4  setosa
# 16          3.9  setosa
# 17          3.5  setosa
# 18          3.8  setosa
# 19          3.8  setosa

# %% [markdown]
# **(2) loc를 이용한 이름이용 방법**

# %%
# 첫, 셋째 행만 뽑고싶다면?
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
# sepal_width, species 열만 보고싶다면?
df.loc[]
# Out:
#     sepal_width species
# 0           3.5  setosa
# 1           3.0  setosa
# 2           3.2  setosa
# 3           3.1  setosa
# 4           3.6  setosa
# 5           3.9  setosa
# 6           3.4  setosa
# 7           3.4  setosa
# 8           2.9  setosa
# 9           3.1  setosa
# 10          3.7  setosa
# 11          3.4  setosa
# 12          3.0  setosa
# 13          3.0  setosa
# 14          4.0  setosa
# 15          4.4  setosa
# 16          3.9  setosa
# 17          3.5  setosa
# 18          3.8  setosa
# 19          3.8  setosa

# %%
# 열을 선택하는 축약형도 있습니다.
# Out:
#    sepal_width species
# 0          3.5  setosa
# 1          3.0  setosa
# 2          3.2  setosa
# 3          3.1  setosa
# 4          3.6  setosa

# %% [markdown]
# 그럼 아래 부분만 선택하려면 어떻게 해야 할까요?
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-08-21%2014.32.05.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-08-21%2014.32.05.png)

# %%
# Out:
#    petal_length  petal_width species
# 2           1.3          0.2  setosa
# 3           1.5          0.2  setosa

# %% [markdown]
# ### Filtering을 통한 subset만들기

# %%
# sepal_length가 5이상일 모든 행 출력 하고싶다면?
df[df['sepal_length'] > 5]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 5            5.4          3.9           1.7          0.4  setosa
# 10           5.4          3.7           1.5          0.2  setosa
# 14           5.8          4.0           1.2          0.2  setosa
# 15           5.7          4.4           1.5          0.4  setosa
# 16           5.4          3.9           1.3          0.4  setosa
# 17           5.1          3.5           1.4          0.3  setosa
# 18           5.7          3.8           1.7          0.3  setosa
# 19           5.1          3.8           1.5          0.3  setosa

# %%
# 그럼 sepal_length가 5이상인 행들 중에 petal_width와 species를 출력하고 싶다면?
df[df['sepal_length']> 5][]
# Out:
#     petal_width species
# 0           0.2  setosa
# 5           0.4  setosa
# 10          0.2  setosa
# 14          0.2  setosa
# 15          0.4  setosa
# 16          0.4  setosa
# 17          0.3  setosa
# 18          0.3  setosa
# 19          0.3  setosa

# %%
# loc를 이용한다면?
df.loc[df['sepal_length']> 5,['petal_width', 'species']]
# Out:
#     petal_width species
# 0           0.2  setosa
# 5           0.4  setosa
# 10          0.2  setosa
# 14          0.2  setosa
# 15          0.4  setosa
# 16          0.4  setosa
# 17          0.3  setosa
# 18          0.3  setosa
# 19          0.3  setosa

# %%
# 연습해 봅시다. species의 이름이 'setosa'가 아닌 행들만 출력한다면요?
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species
# 13           4.3          3.0           1.1          0.1  virginica
# 14           5.8          4.0           NaN          0.2  virginica
# 15           5.7          NaN           1.5          0.4  virginica
# 16           5.4          3.9           1.3          0.4  virginica
# 17           5.1          3.5           NaN          0.3  virginica
# 18           5.7          3.8           1.7          0.3  virginica
# 19           5.1          3.8           1.5          0.3  virginica
# 20           5.1          3.5           1.4          0.2  virginica
# 21           4.9          3.0           1.4          0.2  virginica
# 22           4.7          3.2           1.3          0.2  virginica

# %%
# 그럼 행마다 조건을 주고 싶다면??
# sepal_length > 5 이면서 petal_length <1.5인 모든 행은?
# 주의) 조건이 두개 이상이라면 괄호를 잘 써야 합니다!
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 16           5.4          3.9           1.3          0.4  setosa
# 20           5.1          3.5           1.4          0.2  setosa

# %% [markdown]
# ## 중복값 및 missing 확인 및 처리하기

# %% [markdown]
# ### (1). 중복값 처리

# %%
df
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species
# 0            5.1          3.5           1.4          0.2     setosa
# 1            4.9          3.0           1.4          0.2     setosa
# 2            4.7          3.2           1.3          0.2     setosa
# 3            4.6          3.1           1.5          0.2     setosa
# 4            5.0          3.6           1.4          0.2     setosa
# 5            5.4          3.9           1.7          0.4     setosa
# 6            4.6          3.4           1.4          0.3     setosa
# 7            5.0          3.4           1.5          0.2     setosa
# 8            4.4          2.9           1.4          0.2     setosa
# 9            4.9          3.1           1.5          0.1     setosa
# 10           5.4          3.7           1.5          0.2     setosa
# 11           4.8          3.4           1.6          0.2     setosa
# 12           4.8          3.0           NaN          0.1     setosa
# ...

# %%
# 중복 값있는지 확인 하고 갯수 출력하기
df.duplicated(), df.duplicated().sum()
# Out:
# (0     False
#  1     False
#  2     False
#  3     False
#  4     False
#  5     False
#  6     False
#  7     False
#  8     False
#  9     False
#  10    False
#  11    False
#  12    False
#  13    False
#  14    False
#  15    False
#  16    False
#  17    False
#  18    False
#  19    False
#  20     True
#  21     True
#  22     True
#  23    False
#  24    False
#  25    False
#  dtype: bool, 3)

# %%
# 중복값있는 행 출력하기
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 20           5.1          3.5           1.4          0.2  setosa
# 21           4.9          3.0           1.4          0.2  setosa
# 22           4.7          3.2           1.3          0.2  setosa

# %%
# 어디랑 중복된 건지 알수 없으니 중복된 행은 모두 출력해봅시다. keep인자 이용
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 0            5.1          3.5           1.4          0.2  setosa
# 1            4.9          3.0           1.4          0.2  setosa
# 2            4.7          3.2           1.3          0.2  setosa
# 20           5.1          3.5           1.4          0.2  setosa
# 21           4.9          3.0           1.4          0.2  setosa
# 22           4.7          3.2           1.3          0.2  setosa

# %%
# 그럼 모든 열이 중복이 아닌 특정열이 중복인 행들을 출력하고 싶다면요?
# sepal_length~petal_width 까지 중복인 행들을 출력해 봅시다. subset이용
df[df.duplicated(subset=df.columns[0:4])]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species
# 20           5.1          3.5           1.4          0.2     setosa
# 21           4.9          3.0           1.4          0.2     setosa
# 22           4.7          3.2           1.3          0.2     setosa
# 23           5.1          3.5           1.4          0.2  virginica
# 24           4.9          3.0           1.4          0.2  virginica
# 25           4.7          3.2           1.3          0.2  virginica

# %%
# 중복값을 버려 봅시다.
df.drop_duplicates()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species
# 0            5.1          3.5           1.4          0.2     setosa
# 1            4.9          3.0           1.4          0.2     setosa
# 2            4.7          3.2           1.3          0.2     setosa
# 3            4.6          3.1           1.5          0.2     setosa
# 4            5.0          3.6           1.4          0.2     setosa
# 5            5.4          3.9           1.7          0.4     setosa
# 6            4.6          3.4           1.4          0.3     setosa
# 7            5.0          3.4           1.5          0.2     setosa
# 8            4.4          2.9           1.4          0.2     setosa
# 9            4.9          3.1           1.5          0.1     setosa
# 10           5.4          3.7           1.5          0.2     setosa
# 11           4.8          3.4           1.6          0.2     setosa
# 12           4.8          3.0           NaN          0.1     setosa
# ...

# %% [markdown]
# ### (2) missing 처리

# %%
# missing 값 어딧는지 확인해봅시다.
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  species
# 0          False        False         False        False    False
# 1          False        False         False        False    False
# 2          False        False         False        False    False
# 3          False        False         False        False    False
# 4          False        False         False        False    False
# 5          False        False         False        False    False
# 6          False        False         False        False    False
# 7          False        False         False        False    False
# 8          False        False         False        False    False
# 9          False        False         False        False    False
# 10         False        False         False        False    False
# 11         False        False         False        False    False
# 12         False        False          True        False    False
# ...

# %%
# 각 컬럼별 missing갯수 확인해 봅시다.
# Out:
# sepal_length    0
# sepal_width     1
# petal_length    3
# petal_width     0
# species         0
# dtype: int64

# %%
# missing이 들어있는 행을 버려 봅시다.
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species
# 0            5.1          3.5           1.4          0.2     setosa
# 1            4.9          3.0           1.4          0.2     setosa
# 2            4.7          3.2           1.3          0.2     setosa
# 3            4.6          3.1           1.5          0.2     setosa
# 4            5.0          3.6           1.4          0.2     setosa
# 5            5.4          3.9           1.7          0.4     setosa
# 6            4.6          3.4           1.4          0.3     setosa
# 7            5.0          3.4           1.5          0.2     setosa
# 8            4.4          2.9           1.4          0.2     setosa
# 9            4.9          3.1           1.5          0.1     setosa
# 10           5.4          3.7           1.5          0.2     setosa
# 11           4.8          3.4           1.6          0.2     setosa
# 13           4.3          3.0           1.1          0.1  virginica
# ...

# %%
len(df), len(df.dropna())
# Out:
# (26, 22)

# %% [markdown]
# ## Summarize data

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# 데이터 차원 구해봅시다.
# Out:
# (26, 5)

# %%
# 열 마다 데이터 타입을 확인해봅시다.
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
# 범주형 열(species)의 level별 분포를봅시다.
# 연속형 열은 의미 없습니다.
# Out:
# setosa       16
# virginica    10
# Name: species, dtype: int64

# %%
# 그럼 연속형 열은? -> 히스토그램으로 봅니다.
# import matplotlib.pyplot as plt
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x126731160>,
# ...
#       dtype=object)

# %%
# bin 구간을 설정할 수도 있습니다.
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x126ac7208>,
# ...
#       dtype=object)

# %%
# 그림을 본김에 연속형 변수의 산점도도 확인 할 수 있겠네요
# x축을 'sepal_length' y축을 'petal_length'로 보겠습니다.
df.plot.scatter(x='sepal_length', y='petal_length')

# %%
# 연속형 col의 summary statistics 출력해 봅시다.
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count     26.000000    25.000000     23.000000    26.000000
# mean       5.003846     3.384000      1.430435     0.226923
# std        0.385207     0.335012      0.132921     0.082741
# min        4.300000     2.900000      1.100000     0.100000
# 25%        4.725000     3.100000      1.400000     0.200000
# 50%        4.950000     3.400000      1.400000     0.200000
# 75%        5.100000     3.600000      1.500000     0.275000
# max        5.800000     4.000000      1.700000     0.400000

# %%
# 범주형 까지 보고싶다면요?
df.describe(include='all')
# Out:
#         sepal_length  sepal_width  petal_length  petal_width species
# count      26.000000    25.000000     23.000000    26.000000      26
# unique           NaN          NaN           NaN          NaN       2
# top              NaN          NaN           NaN          NaN  setosa
# freq             NaN          NaN           NaN          NaN      16
# mean        5.003846     3.384000      1.430435     0.226923     NaN
# std         0.385207     0.335012      0.132921     0.082741     NaN
# min         4.300000     2.900000      1.100000     0.100000     NaN
# 25%         4.725000     3.100000      1.400000     0.200000     NaN
# 50%         4.950000     3.400000      1.400000     0.200000     NaN
# 75%         5.100000     3.600000      1.500000     0.275000     NaN
# max         5.800000     4.000000      1.700000     0.400000     NaN

# %%
# 연속형 col의 box plot을 그려봅시다.

# %%
# 그밖에도 다양한 기초 통계와 관련된 함수가 마련되어 있습니다.
# sum, count, median, mean, var, std, max, min
df.mean()
# Out:
# sepal_length    5.003846
# sepal_width     3.384000
# petal_length    1.430435
# petal_width     0.226923
# dtype: float64

# %% [markdown]
# ## Apply 함수 사용해보기
# python의 map()함수를 pandas Dataframe화 시켜놓은 것으로 생각하면 이해가 쉬..우나<br>
# python map을 모른다해도 괜찮아유~

# %% [markdown]
# **map 함수를 알아봅시다**

# %%
def power(val):
    return val**2

value = [1,2,3]

# %%
# 제곱함수를 쓰려면?
# Out:
# 1
# 4
# 9

# %%
# map함수를 이용하면?
list(map(power, value))
# Out:
# [1, 4, 9]

# %% [markdown]
# **그럼 apply함수를 알아봅시다**

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# 'sepal_length'를 제곱하기위해 위에서 만든 함수를 이용하려면?
df['sepal_length'].apply(power)
# Out:
# 0     26.01
# 1     24.01
# 2     22.09
# 3     21.16
# 4     25.00
# 5     29.16
# 6     21.16
# 7     25.00
# 8     19.36
# 9     24.01
# 10    29.16
# 11    23.04
# 12    23.04
# 13    18.49
# 14    33.64
# 15    32.49
# 16    29.16
# 17    26.01
# 18    32.49
# 19    26.01
# 20    26.01
# 21    24.01
# 22    22.09
# 23    26.01
# 24    24.01
# 25    22.09
# Name: sepal_length, dtype: float64

# %% [markdown]
# **lambda 함수를 아십니까?**
#
# 몰라도 됩니다.<br>
# 람다는 map이나 apply함수를 써야 할때 간단한 사용자 정의 함수를 만들기 위해(def가 번거로워서) 쓰는 거니까요.

# %%
# map을 예로 들면?
# Out:
# [1, 4, 9]

# %%
# apply를 예로 들면?
df['sepal_length'].apply()
# Out:
# 0     26.01
# 1     24.01
# 2     22.09
# 3     21.16
# 4     25.00
# 5     29.16
# 6     21.16
# 7     25.00
# 8     19.36
# 9     24.01
# 10    29.16
# 11    23.04
# 12    23.04
# 13    18.49
# 14    33.64
# 15    32.49
# 16    29.16
# 17    26.01
# 18    32.49
# 19    26.01
# 20    26.01
# 21    24.01
# 22    22.09
# 23    26.01
# 24    24.01
# 25    22.09
# Name: sepal_length, dtype: float64

# %%
# quiz! 그럼 species 이름의 앞 세글자만 출력하려면?
# Out:
# 0    set
# 1    set
# 2    set
# 3    set
# 4    set
# Name: species, dtype: object

# %%
# quiz2 species 이름 길이가 6개가 아닌 모든 열을 출력하려면?
def check_name(row):



df[df['species'].apply(check_name)]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species
# 13           4.3          3.0           1.1          0.1  virginica
# 14           5.8          4.0           NaN          0.2  virginica
# 15           5.7          NaN           1.5          0.4  virginica
# 16           5.4          3.9           1.3          0.4  virginica
# 17           5.1          3.5           NaN          0.3  virginica
# 18           5.7          3.8           1.7          0.3  virginica
# 19           5.1          3.8           1.5          0.3  virginica
# 23           5.1          3.5           1.4          0.2  virginica
# 24           4.9          3.0           1.4          0.2  virginica
# 25           4.7          3.2           1.3          0.2  virginica

# %%
# quiz3 sepal_width의 값이 3.5 이하인 모든 열을 출력하고 싶다면?
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species
# 1            4.9          3.0           1.4          0.2     setosa
# 2            4.7          3.2           1.3          0.2     setosa
# 3            4.6          3.1           1.5          0.2     setosa
# 6            4.6          3.4           1.4          0.3     setosa
# 7            5.0          3.4           1.5          0.2     setosa
# 8            4.4          2.9           1.4          0.2     setosa
# 9            4.9          3.1           1.5          0.1     setosa
# 11           4.8          3.4           1.6          0.2     setosa
# 12           4.8          3.0           NaN          0.1     setosa
# 13           4.3          3.0           1.1          0.1  virginica
# 21           4.9          3.0           1.4          0.2     setosa
# 22           4.7          3.2           1.3          0.2     setosa
# 24           4.9          3.0           1.4          0.2  virginica
# ...

# %% [markdown]
# ## 새 컬럼 생성하기

# %%
# setosa면 부채붓꽃, virginica면 버지니카란 이름의 ko_species열을 추가
def conv_name(row):
    if row == "setosa":
        return "부채붓꽃"
    else:
        return "버지니카"

# %%
df['ko_species'] = df['species'].apply(conv_name)
df
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species ko_species
# 0            5.1          3.5           1.4          0.2     setosa       부채붓꽃
# 1            4.9          3.0           1.4          0.2     setosa       부채붓꽃
# 2            4.7          3.2           1.3          0.2     setosa       부채붓꽃
# 3            4.6          3.1           1.5          0.2     setosa       부채붓꽃
# 4            5.0          3.6           1.4          0.2     setosa       부채붓꽃
# 5            5.4          3.9           1.7          0.4     setosa       부채붓꽃
# 6            4.6          3.4           1.4          0.3     setosa       부채붓꽃
# 7            5.0          3.4           1.5          0.2     setosa       부채붓꽃
# 8            4.4          2.9           1.4          0.2     setosa       부채붓꽃
# 9            4.9          3.1           1.5          0.1     setosa       부채붓꽃
# 10           5.4          3.7           1.5          0.2     setosa       부채붓꽃
# ...

# %%
# 표준정규분포를 따르는 랜덤값 열 'standardnorm' 추가
import numpy as np
# Out:
# array([ 0.19736937, -0.42210793, -1.38562321, -0.76819839, -2.67534061,
#        -0.25067161,  0.81351043, -0.78885527,  0.12111087, -3.1440681 ,
#        -0.71660422,  0.68305715, -0.91480632, -1.62020872, -0.42423411,
#        -1.71530448,  1.35161495, -0.21959881,  0.14962959,  0.22583341,
#         0.81165958,  0.80905927, -0.22050452, -0.86009882, -0.31659525,
#         0.38648876])

# %%
df['standardnorm'] = pd.Series(np.random.randn(len(df)))
df
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species  \
# 0            5.1          3.5           1.4          0.2     setosa
# 1            4.9          3.0           1.4          0.2     setosa
# 2            4.7          3.2           1.3          0.2     setosa
# 3            4.6          3.1           1.5          0.2     setosa
# 4            5.0          3.6           1.4          0.2     setosa
# 5            5.4          3.9           1.7          0.4     setosa
# 6            4.6          3.4           1.4          0.3     setosa
# 7            5.0          3.4           1.5          0.2     setosa
# 8            4.4          2.9           1.4          0.2     setosa
# 9            4.9          3.1           1.5          0.1     setosa
# 10           5.4          3.7           1.5          0.2     setosa
# 11           4.8          3.4           1.6          0.2     setosa
# 12           4.8          3.0           NaN          0.1     setosa
# ...

# %% [markdown]
# ## Reshaping DataFrame

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species ko_species  \
# 0           5.1          3.5           1.4          0.2  setosa       부채붓꽃
# 1           4.9          3.0           1.4          0.2  setosa       부채붓꽃
# 2           4.7          3.2           1.3          0.2  setosa       부채붓꽃
# 3           4.6          3.1           1.5          0.2  setosa       부채붓꽃
# 4           5.0          3.6           1.4          0.2  setosa       부채붓꽃
#
#    standardnorm
# 0     -1.325930
# 1      0.565273
# 2     -0.708991
# 3      0.933413
# 4      1.363615

# %% [markdown]
# **(1) 정렬**

# %%
# 'sepal_length'에 대하여 오름차순 정렬을 하고싶다면
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species  \
# 13           4.3          3.0           1.1          0.1  virginica
# 8            4.4          2.9           1.4          0.2     setosa
# 3            4.6          3.1           1.5          0.2     setosa
# 6            4.6          3.4           1.4          0.3     setosa
# 25           4.7          3.2           1.3          0.2  virginica
# 22           4.7          3.2           1.3          0.2     setosa
# 2            4.7          3.2           1.3          0.2     setosa
# 11           4.8          3.4           1.6          0.2     setosa
# 12           4.8          3.0           NaN          0.1     setosa
# 9            4.9          3.1           1.5          0.1     setosa
# 1            4.9          3.0           1.4          0.2     setosa
# 24           4.9          3.0           1.4          0.2  virginica
# 21           4.9          3.0           1.4          0.2     setosa
# ...

# %%
# 반대로 'sepal_length'에 대하여 내림차순 정렬 하고 싶다면?
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species  \
# 14           5.8          4.0           NaN          0.2  virginica
# 18           5.7          3.8           1.7          0.3  virginica
# 15           5.7          NaN           1.5          0.4  virginica
# 10           5.4          3.7           1.5          0.2     setosa
# 16           5.4          3.9           1.3          0.4  virginica
#
#    ko_species  standardnorm
# 14       버지니카     -0.176159
# 18       버지니카     -0.545123
# 15       버지니카      0.652846
# 10       부채붓꽃      0.777584
# 16       버지니카      0.611658

# %%
# 그럼 두 컬럼 'sepal_length', 'petal_length'에 대하여 부분 정렬로 내림차순을 하고싶다면? 
df.sort_values(['sepal_length', 'petal_length'], ascending=False).head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species  \
# 14           5.8          4.0           NaN          0.2  virginica
# 18           5.7          3.8           1.7          0.3  virginica
# 15           5.7          NaN           1.5          0.4  virginica
# 5            5.4          3.9           1.7          0.4     setosa
# 10           5.4          3.7           1.5          0.2     setosa
#
#    ko_species  standardnorm
# 14       버지니카     -0.176159
# 18       버지니카     -0.545123
# 15       버지니카      0.652846
# 5        부채붓꽃      1.790791
# 10       부채붓꽃      0.777584

# %%
# 그럼 부분정렬할때 'sepal_length'는 내림 차순, 'petal_length'는 오름 차순 정렬 하고 싶다면?
df2 = df.sort_values(['sepal_length', 'petal_length'], ascending=)
df2.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species  \
# 14           5.8          4.0           NaN          0.2  virginica
# 15           5.7          NaN           1.5          0.4  virginica
# 18           5.7          3.8           1.7          0.3  virginica
# 16           5.4          3.9           1.3          0.4  virginica
# 10           5.4          3.7           1.5          0.2     setosa
#
#    ko_species     snorm
# 14       버지니카 -0.176159
# 15       버지니카  0.652846
# 18       버지니카 -0.545123
# 16       버지니카  0.611658
# 10       부채붓꽃  0.777584

# %%
# 인덱스를 다시 초기화 하고 싶다면?
df2.reset_index().head()
# Out:
#    index  sepal_length  sepal_width  petal_length  petal_width    species  \
# 0     14           5.8          4.0           NaN          0.2  virginica
# 1     15           5.7          NaN           1.5          0.4  virginica
# 2     18           5.7          3.8           1.7          0.3  virginica
# 3     16           5.4          3.9           1.3          0.4  virginica
# 4     10           5.4          3.7           1.5          0.2     setosa
#
#   ko_species     snorm
# 0       버지니카 -0.176159
# 1       버지니카  0.652846
# 2       버지니카 -0.545123
# 3       버지니카  0.611658
# 4       부채붓꽃  0.777584

# %% [markdown]
# **(2) 컬럼 이름 변경**

# %%
# srandardnorm 컬럼 이름을 snorm으로 바꾸고 싶다면?
df = df.rename(columns={'standardnorm': 'snorm'})
df
# Out:
#     sepal_length  sepal_width  petal_length  petal_width    species  \
# 0            5.1          3.5           1.4          0.2     setosa
# 1            4.9          3.0           1.4          0.2     setosa
# 2            4.7          3.2           1.3          0.2     setosa
# 3            4.6          3.1           1.5          0.2     setosa
# 4            5.0          3.6           1.4          0.2     setosa
# 5            5.4          3.9           1.7          0.4     setosa
# 6            4.6          3.4           1.4          0.3     setosa
# 7            5.0          3.4           1.5          0.2     setosa
# 8            4.4          2.9           1.4          0.2     setosa
# 9            4.9          3.1           1.5          0.1     setosa
# 10           5.4          3.7           1.5          0.2     setosa
# 11           4.8          3.4           1.6          0.2     setosa
# 12           4.8          3.0           NaN          0.1     setosa
# ...

# %% [markdown]
# **(3) melt**<br>
# **(4) pivot**
#
# 위 두 주제는 빠져있습니다. 직접 공부하면서 본 노트북을 채워보시길 추천해요~

# %% [markdown]
# ## 두 데이터 합치기
# 두 데이터 프레임을 합쳐 봅시다.

# %% [markdown]
# **(1) concat : 두 df를 행으로 합치기**

# %%
df1 = pd.DataFrame([['c', 3], ['b', 2]], columns=['letter', 'number'])
df1
# Out:
#   letter  number
# 0      c       3
# 1      b       2

# %%
df2 = pd.DataFrame([['a', 1], [4, 'd']], columns=['number', 'letter'])
df2
# Out:
#   number letter
# 0      a      1
# 1      4      d

# %%
# 두 df를 행으로 합쳐봅니다. 
# 이때 데이터는 헤더 기준으로 합쳐 집니다.
# Out:
# /Users/hyeong-gieun/miniconda3/envs/jupyter/lib/python3.7/site-packages/ipykernel_launcher.py:3: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   This is separate from the ipykernel package so we can avoid doing imports until
#   letter number
# 0      1      a
# 1      d      4
# 0      c      3
# 1      b      2

# %%
# 그럼 합치려는 df가 열이 더 많다면요?
df3 = pd.DataFrame([['c', 3, 'cat'], ['d', 4, 'dog']],
                   columns=['letter', 'number', 'animal'])
df3
# Out:
#   letter  number animal
# 0      c       3    cat
# 1      d       4    dog

# %%
# 데이터가 없는 부분은 missing 으로 처리 되고 합쳐 집니다.
df4 = pd.concat([df1, df3])
df4
# Out:
# /Users/hyeong-gieun/miniconda3/envs/jupyter/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#   animal letter  number
# 0    NaN      c       3
# 1    NaN      b       2
# 0    cat      c       3
# 1    dog      d       4

# %%
# quiz 복습. missing된 행을 버리고 싶다면요?
df4.
# Out:
#   animal letter  number
# 0    cat      c       3
# 1    dog      d       4

# %%
# quiz! missing이 있는 열을 버리고 싶다면요??
df4.
# Out:
#   letter  number
# 0      c       3
# 1      b       2
# 0      c       3
# 1      d       4

# %%
# quiz df4의 인덱스를 초기화 하고싶으면요 ??
df4.
# Out:
#    index animal letter  number
# 0      0    NaN      c       3
# 1      1    NaN      b       2
# 2      0    cat      c       3
# 3      1    dog      d       4

# %% [markdown]
# **(2) merge : 두 df를 열로 합치기**

# %%
df1 = pd.DataFrame({"x1": ["한국", "미국", "중국"], "x2": [1, 2, 3]})
df1
# Out:
#    x1  x2
# 0  한국   1
# 1  미국   2
# 2  중국   3

# %%
df2 = pd.DataFrame({"x1": ["한국", "미국", "영국"], "x3": ["T", "F", "T"]})
df2
# Out:
#    x1 x3
# 0  한국  T
# 1  미국  F
# 2  영국  T

# %%
# x1을 기준으로 df1과 df2를 합쳐보자
# default로 how=inner라 공통 행만 남는다.
pd.merge(df1, df2, on=['x1'])
# Out:
#    x1  x2 x3
# 0  한국   1  T
# 1  미국   2  F

# %%
# df2 데이터 기준으로 df1을 합치고 싶다면?
pd.merge(df1, df2, on=['x1'], )
# Out:
#    x1   x2 x3
# 0  한국  1.0  T
# 1  미국  2.0  F
# 2  영국  NaN  T

# %%
# df1과 df2 모든 데이터를 살리며 합집합 하고 싶다면?
pd.merge(df1, df2, on=['x1'], )
# Out:
#    x1   x2   x3
# 0  한국  1.0    T
# 1  미국  2.0    F
# 2  중국  3.0  NaN
# 3  영국  NaN    T

# %%
# 그럼 한 열말고 두 열을 기준으로 합치고 싶다면??
df3 = pd.DataFrame({"x1": ["한국", "미국", "중국"], "x2": ['사과','배','수박'], "x3": ["D", "F", "W"]})
df3
# Out:
#    x1  x2 x3
# 0  한국  사과  D
# 1  미국   배  F
# 2  중국  수박  W

# %%
df4 = pd.DataFrame({"x1": ["한국", "미국", "영국"], "x2": ['사과','오렌지','호박'], "x4": ['데이터', '만들기', '어렵다']})
df4
# Out:
#    x1   x2   x4
# 0  한국   사과  데이터
# 1  미국  오렌지  만들기
# 2  영국   호박  어렵다

# %%
# x1과 x2열 기준으로 합쳐본다.
pd.merge(df3, df4, on=[])
# Out:
#    x1  x2 x3   x4
# 0  한국  사과  D  데이터

# %%
# 각 행이 어떻게 merge된건지 출처를 알고 싶을 때 indicator를 씀
pd.merge(df3, df4, on=['x1', 'x2'], how='outer', indicator=True)
# Out:
#    x1   x2   x3   x4      _merge
# 0  한국   사과    D  데이터        both
# 1  미국    배    F  NaN   left_only
# 2  중국   수박    W  NaN   left_only
# 3  미국  오렌지  NaN  만들기  right_only
# 4  영국   호박  NaN  어렵다  right_only

# %%
# quiz, left_only인 것만 따로 새로운 df에 저장해 보세요~
# Out:
#    x1  x2 x3   x4     _merge
# 1  미국   배  F  NaN  left_only
# 2  중국  수박  W  NaN  left_only

# %%
# 두 df가 합쳐질 기준 열의 이름이 다를 경우는요?

# %%
df1
# Out:
#    x1  x2
# 0  한국   1
# 1  미국   2
# 2  중국   3

# %%
df10 = pd.DataFrame({'a':['한국', '미국'], 'b':[5, 6]})
df10
# Out:
#     a  b
# 0  한국  5
# 1  미국  6

# %%
pd.merge(df1, df10, left_on='x1', right_on='a')
# Out:
#    x1  x2   a  b
# 0  한국   1  한국  5
# 1  미국   2  미국  6
